# %%
#Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid")
import os
import glob as gb
import cv2
import tensorflow as tf
import keras
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

ws = gc.open_by_key('1Ei5-1ikQkTHZPXpUIcVQuCypWuJHPKQLTbqiJiMTlr4')
ws=ws.worksheet("number_of_samples")

# get_all_values gives a list of rows.
rows = ws.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
result=pd.DataFrame.from_records(rows)
print(result)

# file_info=pd.read_csv("/content/drive/MyDrive/deepLearning/cars_classification/dataset/num_of_sample.csv")
# Out:
# [['', 'Name of class', 'Number of files'], ['0', 'bmw serie 1', '82'], ['1', 'chevrolet spark', '108'], ['2', 'chevroulet aveo', '129'], ['3', 'clio', '344'], ['4', 'duster', '280'], ['5', 'Golf', '160'], ['6', 'hyundai i10', '130'], ['7', 'hyundai tucson', '128'], ['8', 'logan', '112'], ['9', 'megane', '280'], ['10', 'mercedes class a', '84'], ['11', 'nemo citroen', '80'], ['12', 'octavia', '156'], ['13', 'picanto', '178'], ['14', 'polo', '132'], ['15', 'sandero', '260'], ['16', 'seat ibiza', '100'], ['17', 'symbol', '158'], ['18', 'toyota corolla', '150'], ['19', 'volkswagen tiguan', '184']]
#      0                  1                2
# 0           Name of class  Number of files
# 1    0        bmw serie 1               82
# 2    1    chevrolet spark              108
# 3    2    chevroulet aveo              129
# 4    3               clio              344
# 5    4             duster              280
# 6    5               Golf              160
# 7    6        hyundai i10              130
# 8    7     hyundai tucson              128
# 9    8              logan              112
# 10   9             megane              280
# 11  10   mercedes class a               84
# 12  11       nemo citroen               80
# 13  12            octavia              156
# 14  13            picanto              178
# 15  14               polo              132
# 16  15            sandero              260
# 17  16         seat ibiza              100
# 18  17             symbol              158
# 19  18     toyota corolla              150
# 20  19  volkswagen tiguan              184

# %%
new_header = result.iloc[0] #grab the first row for the header
result = result[1:] #take the data less the header row
result.columns = new_header
result.rename(columns = {'':'code'}, inplace = True)
print((result))
# Out:
# 0  code      Name of class Number of files
# 1     0        bmw serie 1              82
# 2     1    chevrolet spark             108
# 3     2    chevroulet aveo             129
# 4     3               clio             344
# 5     4             duster             280
# 6     5               Golf             160
# 7     6        hyundai i10             130
# 8     7     hyundai tucson             128
# 9     8              logan             112
# 10    9             megane             280
# 11   10   mercedes class a              84
# 12   11       nemo citroen              80
# 13   12            octavia             156
# 14   13            picanto             178
# 15   14               polo             132
# 16   15            sandero             260
# 17   16         seat ibiza             100
# 18   17             symbol             158
# 19   18     toyota corolla             150
# 20   19  volkswagen tiguan             184

# %%
result={'Name of class':list(result['Name of class']),'Number of files':list(result['Number of files'].astype(int)),'code':list(result['code'].astype(int))}

# %%
result=pd.DataFrame(result)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name of class    20 non-null     object
#  1   Number of files  20 non-null     int64
#  2   code             20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 608.0+ bytes

# %%
sns.barplot(data=result, x="Number of files", y="Name of class")

# %%
flat_list = list(result["Name of class"])
print(flat_list)

codes = dict(zip(result["Name of class"], result["code"]))
codes
# Out:
# ['bmw serie 1', 'chevrolet spark', 'chevroulet aveo', 'clio', 'duster', 'Golf', 'hyundai i10', 'hyundai tucson', 'logan', 'megane', 'mercedes class a', 'nemo citroen', 'octavia', 'picanto', 'polo', 'sandero', 'seat ibiza', 'symbol', 'toyota corolla', 'volkswagen tiguan']
# {'bmw serie 1': 0,
#  'chevrolet spark': 1,
#  'chevroulet aveo': 2,
#  'clio': 3,
#  'duster': 4,
#  'Golf': 5,
#  'hyundai i10': 6,
#  'hyundai tucson': 7,
#  'logan': 8,
#  'megane': 9,
#  'mercedes class a': 10,
#  'nemo citroen': 11,
#  'octavia': 12,
#  'picanto': 13,
#  'polo': 14,
#  'sandero': 15,
#  'seat ibiza': 16,
#  'symbol': 17,
#  'toyota corolla': 18,
#  'volkswagen tiguan': 19}

# %%
def getcode(n) : 
    for x , y in codes.items() : 
        if n == y : 
            return x

# %%
input_folder = "/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA"

for subdir, dirs, files in os.walk(input_folder):
    for file in files:
        print(os.path.join(subdir, file))
# Out:
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back472.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back475.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back474.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back476.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back477.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back478.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back479.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back480.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back481.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back482.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back483.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back484.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back485.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back486.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back487.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back488.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back489.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back490.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back491.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back492.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back493.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back496.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back498.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back500.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back502.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back503.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back504.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back505.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back507.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back509.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back510.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back511.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back512.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back513.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back514.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back515.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back516.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back518.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back519.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back520.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back521.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back522.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back523.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back524.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back526.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back528.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back529.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back531.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back533.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back534.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back535.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back536.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back537.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back538.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back540.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back541.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back542.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back543.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back545.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back544.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back546.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back547.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back548.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back549.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back550.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/back551.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car472.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car474.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car475.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car476.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car477.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car478.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car479.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car480.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car481.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car482.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car483.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car484.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car485.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car486.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car487.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car488.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car489.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car490.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car491.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car492.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car493.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car496.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car498.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car500.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car502.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car503.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car504.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car505.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car507.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car508.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car509.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car510.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car511.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car512.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car513.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car514.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car515.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car516.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car518.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car519.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car520.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car521.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car522.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car523.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car524.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car526.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car528.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car529.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car531.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car533.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car534.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car535.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car536.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car537.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car538.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car540.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car541.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car542.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car543.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car544.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car545.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car546.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car547.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car548.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car549.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car550.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf/car551.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back0.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back10.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back11.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back12.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back13.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back15.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back14.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back16.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back17.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back19.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back18.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back2.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back20.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back21.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back23.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back24.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back22.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back25.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back26.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back27.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back28.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back29.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back3.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back31.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back33.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back34.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back35.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back36.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back38.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back6.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back7.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back8.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/back9.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car0.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car10.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car11.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car12.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car14.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car15.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car16.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car17.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car18.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car19.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car2.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car20.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car21.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car22.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car24.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car25.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car26.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car27.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car28.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car3.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car29.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car30.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car31.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car32.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car33.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car34.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car35.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car37.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car39.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car4.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car40.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car5.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1/car7.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back41.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back42.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back43.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back44.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back45.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back46.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back47.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back49.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back50.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back51.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back52.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back53.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back54.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back55.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back56.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back57.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back59.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back58.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back60.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back61.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back62.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back63.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back64.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back65.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back66.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back67.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back68.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back69.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back70.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back71.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back72.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back73.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back74.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back75.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back76.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back77.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back78.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back79.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back80.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back81.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back82.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back83.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back84.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back85.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back86.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back87.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back88.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back89.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back90.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back91.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back92.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/back93.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car41.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car42.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car43.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car44.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car45.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car46.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car47.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car49.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car50.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car51.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car52.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car53.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/car54.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark/
jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1541.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1542.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1543.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1544.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1545.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1546.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1547.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1548.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1549.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1550.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1551.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1552.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1553.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1554.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1555.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1556.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1557.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1558.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1560.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1559.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1561.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1562.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1563.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1564.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1565.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1566.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1567.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1568.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1569.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1570.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1571.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1572.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1573.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1574.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1575.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1576.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1577.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1578.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1579.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1580.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1581.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1583.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1582.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1584.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1585.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1586.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1587.jpg
# /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan/car1589.jpg

# %%
N = 0  # total files
Number_of_files = []
for subdir, dirs, files in os.walk(input_folder):
    N_c = len(files)
    N += N_c
    print ("Files in ", subdir, N_c)
    if len(files) < 1:
        continue 
    Number_of_files.append(len(files))
print( "Total Files ",N)

#print(Number_of_files)
Directory_Name = os.listdir(input_folder)
#Directory_Name

df = pd.DataFrame({"Directory_Name": Directory_Name,
                   "Number_of_files": Number_of_files})
print(df)

ax = sns.barplot(data = df, x=Number_of_files, y=Directory_Name, orient="h", color="y")
# Out:
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA 0
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf 133
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1 66
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark 104
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevroulet aveo 115
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/clio 278
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/duster 235
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/hyundai i10 118
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/hyundai tucson 118
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/logan 48
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/megane 235
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/mercedes class a 68
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/nemo citroen 72
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/octavia 146
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/picanto 133
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/polo 114
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/sandero 225
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/seat ibiza 84
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/symbol 148
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/toyota corolla 147
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan 165
# Total Files  2752
#        Directory_Name  Number_of_files
# 0                Golf              133
# 1         bmw serie 1               66
# 2     chevrolet spark              104
# 3     chevroulet aveo              115
# 4                clio              278
# 5              duster              235
# 6         hyundai i10              118
# 7      hyundai tucson              118
# 8               logan               48
# 9              megane              235
# 10   mercedes class a               68
# 11       nemo citroen               72
# 12            octavia              146
# 13            picanto              133
# 14               polo              114
# 15            sandero              225
# 16         seat ibiza               84
# 17             symbol              148
# 18     toyota corolla              147
# 19  volkswagen tiguan              165

# %%
fnames = os.listdir(input_folder)
fnames = sorted(fnames)
num_files = len(fnames)
images_list = []
obj = {}
i = 0

    
while i < num_files:
    images_list = []
    files= os.listdir(input_folder+'/'+fnames[i])
    for file in files:
      images_list.append(os.path.join(input_folder+'/'+fnames[i], file))
    obj[fnames[i]] = images_list 
    i += 1
    
obj.keys()
# Out:
# dict_keys(['Golf', 'bmw serie 1', 'chevrolet spark', 'chevroulet aveo', 'clio', 'duster', 'hyundai i10', 'hyundai tucson', 'logan', 'megane', 'mercedes class a', 'nemo citroen', 'octavia', 'picanto', 'polo', 'sandero', 'seat ibiza', 'symbol', 'toyota corolla', 'volkswagen tiguan'])

# %%
# pip install imagehash

# %%
# remove image duplication in python
# pip install imagehash
# from PIL import Image
# import imagehash

# # image_fns : List of training image files
# for key, value in obj.items():
#  image_fns = value
 
#  #print(image_fns)
#  img_hashes = {}

#  for img_fn in sorted(image_fns):
#     hash = imagehash.average_hash(Image.open(img_fn))
#     if hash in img_hashes:
#         #print( '{} duplicate of {}'.format(img_fn, img_hashes[hash]) )
#         #print('************************************************************')
#         os.remove(img_fn)
        
#     else:
#         img_hashes[hash] = img_fn

# %%
# list total files, average per class, and any class has < 100 images
a=[]
N = 0  # total files
Number_of_files = []
for subdir, dirs, files in os.walk(input_folder):
    N_c = len(files)
    N += N_c
    print ("Files in ", subdir, N_c)
    if N_c>0 and N_c<100: 
     a.append(subdir)
    if len(files) < 1:
        continue 
    Number_of_files.append(len(files))
print( "Total Files ",N)
print( "Average Files ",N/20)
print(a)

#print(Number_of_files)
Directory_Name = os.listdir(input_folder)
#Directory_Name

df = pd.DataFrame({"Directory_Name": Directory_Name,
                   "Number_of_files": Number_of_files})
print(df)

ax = sns.barplot(data = df, x=Number_of_files, y=Directory_Name, orient="h", color="r")
# Out:
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA 0
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/Golf 133
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1 66
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevrolet spark 104
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/chevroulet aveo 115
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/clio 278
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/duster 235
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/hyundai i10 118
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/hyundai tucson 118
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/logan 48
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/megane 235
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/mercedes class a 68
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/nemo citroen 72
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/octavia 146
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/picanto 133
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/polo 114
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/sandero 225
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/seat ibiza 84
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/symbol 148
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/toyota corolla 147
# Files in  /content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/volkswagen tiguan 165
# Total Files  2752
# Average Files  137.6
# ['/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/bmw serie 1', '/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/logan', '/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/mercedes class a', '/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/nemo citroen', '/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA/seat ibiza']
#        Directory_Name  Number_of_files
# 0                Golf              133
# 1         bmw serie 1               66
# 2     chevrolet spark              104
# 3     chevroulet aveo              115
# 4                clio              278
# 5              duster              235
# 6         hyundai i10              118
# 7      hyundai tucson              118
# 8               logan               48
# 9              megane              235
# 10   mercedes class a               68
# 11       nemo citroen               72
# 12            octavia              146
# 13            picanto              133
# 14               polo              114
# 15            sandero              225
# 16         seat ibiza               84
# 17             symbol              148
# 18     toyota corolla              147
# 19  volkswagen tiguan              165

# %%
# pip install split-folders

# %%
# import splitfolders
# input_folder = "/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA"


# output = "/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA2"  #where you want the split datasets saved. one will be created if it does not exist or none is set

# splitfolders.ratio(input_folder, output=output, seed=42, ratio=(.7, .2, .1)) # ratio of split are in order of train/val/test. You can change to whatever you want. For train/val sets only, you could do .75, .25 for example.

# %%
trainpath = "/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA2/"
testpath = "/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA2/"
predpath = "/content/drive/MyDrive/deepLearning/cars_classification/dataset/DATA2/"

# %%
N=0
Number_of_files = []
for folder in  os.listdir(trainpath + 'train') : 
    files = gb.glob(pathname= str( trainpath +'train//' + folder + '/*.jpg'))
    N+=len(files)
    print(f'For training data , found {len(files)} in folder {folder}')
    if len(files) < 1:
        continue 
    Number_of_files.append(len(files))
print(N)
print(N/20)

#print(Number_of_files)
Directory_Name = os.listdir(trainpath + 'train')
#Directory_Name

df = pd.DataFrame({"Directory_Name": Directory_Name,
                   "Number_of_files": Number_of_files})
print(df)

ax = sns.barplot(data = df, x=Number_of_files, y=Directory_Name, orient="h", color="gray")
# Out:
# For training data , found 132 in folder volkswagen tiguan
# For training data , found 117 in folder toyota corolla
# For training data , found 118 in folder symbol
# For training data , found 91 in folder polo
# For training data , found 180 in folder sandero
# For training data , found 67 in folder seat ibiza
# For training data , found 116 in folder octavia
# For training data , found 106 in folder picanto
# For training data , found 57 in folder nemo citroen
# For training data , found 188 in folder megane
# For training data , found 54 in folder mercedes class a
# For training data , found 38 in folder logan
# For training data , found 94 in folder hyundai tucson
# For training data , found 94 in folder hyundai i10
# For training data , found 188 in folder duster
# For training data , found 222 in folder clio
# For training data , found 92 in folder chevroulet aveo
# For training data , found 52 in folder bmw serie 1
# For training data , found 83 in folder chevrolet spark
# For training data , found 106 in folder Golf
# 2195
# 109.75
#        Directory_Name  Number_of_files
# 0   volkswagen tiguan              132
# 1      toyota corolla              117
# 2              symbol              118
# 3                polo               91
# 4             sandero              180
# 5          seat ibiza               67
# 6             octavia              116
# 7             picanto              106
# 8        nemo citroen               57
# 9              megane              188
# 10   mercedes class a               54
# 11              logan               38
# 12     hyundai tucson               94
# 13        hyundai i10               94
# 14             duster              188
# 15               clio              222
# 16    chevroulet aveo               92
# 17        bmw serie 1               52
# 18    chevrolet spark               83
# 19               Golf              106

# %%
N=0
Number_of_files = []
for folder in  os.listdir(testpath + 'test') : 
    files = gb.glob(pathname= str( testpath +'test//' + folder + '/*.jpg'))
    N+=len(files)
    print(f'For training data , found {len(files)} in folder {folder}')
    if len(files) < 1:
        continue 
    Number_of_files.append(len(files))
print(N)
print(N/20)

#print(Number_of_files)
Directory_Name = os.listdir(testpath + 'test')
#Directory_Name

df = pd.DataFrame({"Directory_Name": Directory_Name,
                   "Number_of_files": Number_of_files})
print(df)

ax = sns.barplot(data = df, x=Number_of_files, y=Directory_Name, orient="h", color="orange")
# Out:
# For training data , found 17 in folder volkswagen tiguan
# For training data , found 16 in folder toyota corolla
# For training data , found 16 in folder symbol
# For training data , found 13 in folder polo
# For training data , found 23 in folder sandero
# For training data , found 10 in folder seat ibiza
# For training data , found 16 in folder octavia
# For training data , found 14 in folder picanto
# For training data , found 8 in folder nemo citroen
# For training data , found 24 in folder megane
# For training data , found 8 in folder mercedes class a
# For training data , found 6 in folder logan
# For training data , found 13 in folder hyundai tucson
# For training data , found 13 in folder hyundai i10
# For training data , found 24 in folder duster
# For training data , found 29 in folder clio
# For training data , found 12 in folder chevroulet aveo
# For training data , found 8 in folder bmw serie 1
# For training data , found 12 in folder chevrolet spark
# For training data , found 14 in folder Golf
# 296
# 14.8
#        Directory_Name  Number_of_files
# 0   volkswagen tiguan               17
# 1      toyota corolla               16
# 2              symbol               16
# 3                polo               13
# 4             sandero               23
# 5          seat ibiza               10
# 6             octavia               16
# 7             picanto               14
# 8        nemo citroen                8
# 9              megane               24
# 10   mercedes class a                8
# 11              logan                6
# 12     hyundai tucson               13
# 13        hyundai i10               13
# 14             duster               24
# 15               clio               29
# 16    chevroulet aveo               12
# 17        bmw serie 1                8
# 18    chevrolet spark               12
# 19               Golf               14

# %%
N=0
Number_of_files = []
for folder in  os.listdir(predpath + 'val') : 
    files = gb.glob(pathname= str( predpath +'val//' + folder + '/*.jpg'))
    N+=len(files)
    print(f'For prediction data , found {len(files)} in folder {folder}')
    if len(files) < 1:
        continue 
    Number_of_files.append(len(files))
print(N)
print(N/20)

#print(Number_of_files)
Directory_Name = os.listdir(predpath + 'val')
#Directory_Name

df = pd.DataFrame({"Directory_Name": Directory_Name,
                   "Number_of_files": Number_of_files})
print(df)

ax = sns.barplot(data = df, x=Number_of_files, y=Directory_Name, orient="h", color="violet")
# Out:
# For prediction data , found 33 in folder volkswagen tiguan
# For prediction data , found 29 in folder toyota corolla
# For prediction data , found 29 in folder symbol
# For prediction data , found 23 in folder polo
# For prediction data , found 45 in folder sandero
# For prediction data , found 17 in folder seat ibiza
# For prediction data , found 29 in folder octavia
# For prediction data , found 26 in folder picanto
# For prediction data , found 14 in folder nemo citroen
# For prediction data , found 47 in folder megane
# For prediction data , found 13 in folder mercedes class a
# For prediction data , found 9 in folder logan
# For prediction data , found 23 in folder hyundai tucson
# For prediction data , found 23 in folder hyundai i10
# For prediction data , found 47 in folder duster
# For prediction data , found 55 in folder clio
# For prediction data , found 23 in folder chevroulet aveo
# For prediction data , found 13 in folder bmw serie 1
# For prediction data , found 21 in folder chevrolet spark
# For prediction data , found 26 in folder Golf
# 545
# 27.25
#        Directory_Name  Number_of_files
# 0   volkswagen tiguan               33
# 1      toyota corolla               29
# 2              symbol               29
# 3                polo               23
# 4             sandero               45
# 5          seat ibiza               17
# 6             octavia               29
# 7             picanto               26
# 8        nemo citroen               14
# 9              megane               47
# 10   mercedes class a               13
# 11              logan                9
# 12     hyundai tucson               23
# 13        hyundai i10               23
# 14             duster               47
# 15               clio               55
# 16    chevroulet aveo               23
# 17        bmw serie 1               13
# 18    chevrolet spark               21
# 19               Golf               26

# %%
size = []
for folder in  os.listdir(trainpath +'train') : 
    files = gb.glob(pathname= str( trainpath +'train//' + folder + '/*.jpg'))
    for file in files: 
        image = plt.imread(file)
        size.append(image.shape)
pd.Series(size).value_counts()
# Out:
# (224, 224, 3)    2195
# dtype: int64

# %%
size = []
for folder in  os.listdir(testpath +'test') : 
    files = gb.glob(pathname= str( testpath +'test//' + folder + '/*.jpg'))
    for file in files: 
        image = plt.imread(file)
        size.append(image.shape)
pd.Series(size).value_counts()
# Out:
# (224, 224, 3)    296
# dtype: int64

# %%
size = []
#files = gb.glob(pathname= str( predpath +'val/*.jpg'))

for folder in  os.listdir(predpath +'val'): 
 files = gb.glob(pathname= str( predpath +'val//'+ folder + '/*.jpg') )
 for file in files: 
        image = plt.imread(file)
        size.append(image.shape)
pd.Series(size).value_counts()
# Out:
# (224, 224, 3)    545
# dtype: int64

# %%
s=185
batch_size=64

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(64, (5,5), activation='relu', input_shape=(s, s, 3)))
model.add(Conv2D(filters=64, kernel_size=(5,5), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.15))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.15))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.15))
model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(20, activation='softmax'))

# Compilation of the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# model.add(Conv2D(128, (3, 3), activation='relu', input_shape=(s, s, 3)))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(128, (3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(64, (3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))

# model.add(Flatten())
# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(20, activation='softmax')) # 

# model.summary()
# optimizer=keras.optimizers.RMSprop()

# # #KerasModel.compile(optimizer ='rmsprop',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 181, 181, 64)      4864
#
#  conv2d_5 (Conv2D)           (None, 177, 177, 64)      102464
#
#  dropout_4 (Dropout)         (None, 177, 177, 64)      0
#
#  conv2d_6 (Conv2D)           (None, 175, 175, 64)      36928
#
#  dropout_5 (Dropout)         (None, 175, 175, 64)      0
#
#  conv2d_7 (Conv2D)           (None, 173, 173, 64)      36928
#
#  dropout_6 (Dropout)         (None, 173, 173, 64)      0
#
#  flatten_1 (Flatten)         (None, 1915456)           0
#
#  dense_2 (Dense)             (None, 256)               490356992
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 20)                5140
#
# =================================================================
# Total params: 490,543,316
# Trainable params: 490,543,316
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)
callbacks = [earlystop]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# IMAGE_SIZE = 128

train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=10,
        horizontal_flip=True
)
train_generator = train_datagen.flow_from_directory(
        trainpath+"/train",
        target_size=(s,s),
        class_mode='categorical',
        # batch_size=batch_size
)
# Out:
# Found 2195 images belonging to 20 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in train_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_directory(
   predpath+'/val', 
    target_size=(s,s),
   class_mode='categorical',
    # batch_size=batch_size
)
# Out:
# Found 545 images belonging to 20 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in validation_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
history = model.fit(
    train_generator, 
    epochs=50,
    validation_data=validation_generator,
    batch_size=batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 69/69 [==============================] - 35s 467ms/step - loss: 5.2751 - accuracy: 0.0847 - val_loss: 2.9666 - val_accuracy: 0.0881
# Epoch 2/50
# 69/69 [==============================] - 30s 432ms/step - loss: 2.9279 - accuracy: 0.1112 - val_loss: 2.8695 - val_accuracy: 0.1028
# Epoch 3/50
# 69/69 [==============================] - 29s 419ms/step - loss: 2.9009 - accuracy: 0.1021 - val_loss: 2.9130 - val_accuracy: 0.0844
# Epoch 4/50
# 69/69 [==============================] - 29s 420ms/step - loss: 2.8742 - accuracy: 0.1153 - val_loss: 2.7345 - val_accuracy: 0.1468
# Epoch 5/50
# 69/69 [==============================] - 29s 419ms/step - loss: 2.7698 - accuracy: 0.1613 - val_loss: 2.6441 - val_accuracy: 0.1798
# Epoch 6/50
# 69/69 [==============================] - 29s 419ms/step - loss: 2.6628 - accuracy: 0.1913 - val_loss: 2.4922 - val_accuracy: 0.2440
# Epoch 7/50
# 69/69 [==============================] - 29s 417ms/step - loss: 2.5677 - accuracy: 0.2228 - val_loss: 2.4056 - val_accuracy: 0.2697
# Epoch 8/50
# 69/69 [==============================] - 29s 418ms/step - loss: 2.4544 - accuracy: 0.2510 - val_loss: 2.3265 - val_accuracy: 0.3138
# Epoch 9/50
# 69/69 [==============================] - 29s 417ms/step - loss: 2.3364 - accuracy: 0.3039 - val_loss: 2.2252 - val_accuracy: 0.3560
# Epoch 10/50
# 69/69 [==============================] - 30s 438ms/step - loss: 2.2510 - accuracy: 0.3253 - val_loss: 2.2272 - val_accuracy: 0.3596
# Epoch 11/50
# 69/69 [==============================] - 29s 416ms/step - loss: 2.1534 - accuracy: 0.3408 - val_loss: 2.0619 - val_accuracy: 0.4073
# Epoch 12/50
# 69/69 [==============================] - 29s 422ms/step - loss: 2.0412 - accuracy: 0.3768 - val_loss: 2.0197 - val_accuracy: 0.4165
ig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
# ax1.plot(history.history['loss'], color='b', label="Training loss")
# ax1.plot(history.history['val_loss'], color='r', label="validation loss")
# ax1.set_xticks(np.arange(1, 50, 1))
# ax1.set_yticks(np.arange(0, 1, 0.1))

# ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
# ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
# ax2.set_xticks(np.arange(1, 50, 1))

# legend = plt.legend(loc='best', shadow=True)
# plt.tight_layout()
# plt.show()


# def plot_performance(history=None, figure_directory=None, ):
ylim_pad=[0, 0]
xlabel = 'Epoch'
legends = ['Training', 'Validation']
plt.figure(figsize=(20, 5))
y1 = history.history['accuracy']
y2 = history.history['val_accuracy']
min_y = min(min(y1), min(y2))-ylim_pad[0]
max_y = max(max(y1), max(y2))+ylim_pad[0]
plt.subplot(121)
plt.plot(y1)
plt.plot(y2)
plt.title('Model Accuracy\n', fontsize=17)
plt.xlabel(xlabel, fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.ylim(min_y, max_y)
plt.legend(legends, loc='upper left')
plt.grid()
y1 = history.history['loss']
y2 = history.history['val_loss']
min_y = min(min(y1), min(y2))-ylim_pad[1]
max_y = max(max(y1), max(y2))+ylim_pad[1]
plt.subplot(122)
plt.plot(y1)
plt.plot(y2)
plt.title('Model Loss\n', fontsize=17)
plt.xlabel(xlabel, fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.ylim(min_y, max_y)
plt.legend(legends, loc='upper right')
plt.grid()
plt.show()

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_directory(
    testpath+'/test', 
    target_size=(s,s),
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 296 images belonging to 20 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in test_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
predict = model.predict_generator(test_generator)
predicted_classes = np.argmax(predict, axis=1)
# Out:
# <ipython-input-58-0524b258b557>:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predict = model.predict_generator(test_generator)

# %%
from sklearn.metrics import classification_report,confusion_matrix
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys()) 
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
#                    precision    recall  f1-score   support
#
#              Golf       0.44      0.50      0.47        14
#       bmw serie 1       1.00      0.38      0.55         8
#   chevrolet spark       0.60      0.75      0.67        12
#   chevroulet aveo       0.91      0.83      0.87        12
#              clio       0.86      0.86      0.86        29
#            duster       0.83      0.62      0.71        24
#       hyundai i10       0.62      0.77      0.69        13
#    hyundai tucson       0.92      0.85      0.88        13
#             logan       0.71      0.83      0.77         6
#            megane       0.67      0.75      0.71        24
#  mercedes class a       0.88      0.88      0.88         8
#      nemo citroen       0.83      0.62      0.71         8
#           octavia       0.81      0.81      0.81        16
#           picanto       0.89      0.57      0.70        14
#              polo       0.83      0.77      0.80        13
#           sandero       0.65      0.74      0.69        23
#        seat ibiza       0.60      0.60      0.60        10
#            symbol       0.61      0.69      0.65        16
#    toyota corolla       0.69      0.69      0.69        16
# volkswagen tiguan       0.67      0.82      0.74        17
#
#          accuracy                           0.73       296
#         macro avg       0.75      0.72      0.72       296
#      weighted avg       0.75      0.73      0.73       296

# %%
conf_matrix = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize = (14,10))
sns.heatmap(conf_matrix, annot=True)
